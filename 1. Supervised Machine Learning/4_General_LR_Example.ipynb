# %%
import copy, math, numpy as np, pandas as pd, matplotlib.pyplot as plt
from General_LR import compute_model, compute_cost, compute_gradient, gradient_descent
np.set_printoptions(precision=2)  # reduced display precision on numpy arrays

# %%
X_train = np.array([[2104, 5, 1, 45],
                    [1416, 3, 2, 40],
                    [852, 2, 1, 35]])
y_train = np.array([460, 232, 178])

# %%
df1 = pd.DataFrame({"Size": X_train[:, 0],
                    "Number of bedrooms": X_train[:, 1],
                    "Number of floors": X_train[:, 2],
                    "Age of house": X_train[:, 3],
                   "Prices": y_train})
df1
# Out:
#    Size  Number of bedrooms  Number of floors  Age of house  Prices
# 0  2104                   5                 1            45     460
# 1  1416                   3                 2            40     232
# 2   852                   2                 1            35     178

# %%
b_init = 785.1811367994083
w_init = np.array([0.39133535, 18.75376741, -53.36032453, -26.42131618])
print(f"w_init shape: {w_init.shape}, b_init type: {type(b_init)}")
# Out:
# w_init shape: (4,), b_init type: <class 'float'>

# %%
w_final, b_final, J_hist, p_hist = gradient_descent(X_train,
                     y_train,
                     w_in = np.zeros_like(w_init),
                     b_in = 0,
                     alpha = 1.0e-9,
                     num_iters = 5000)

print(f"b, w found by gradient descent: {b_final:0.2f},{w_final} ")
m,_ = X_train.shape
for i in range(m):
    print(f"prediction: {np.dot(X_train[i], w_final) + b_final:0.2f}, target value: {y_train[i]}")
# Out:
# Iteration    0: Cost 49272.07
# Iteration  500: Cost 4609.36
# Iteration 1000: Cost 1039.95
# Iteration 1500: Cost 754.69
# Iteration 2000: Cost 731.89
# Iteration 2500: Cost 730.07
# Iteration 3000: Cost 729.92
# Iteration 3500: Cost 729.91
# Iteration 4000: Cost 729.91
# Iteration 4500: Cost 729.91
# Iteration 5000: Cost 729.91
# b, w found by gradient descent: 0.00,[0.2 0.2 0.2 0.2]
# prediction: 423.75, target value: 460
# prediction: 287.29, target value: 232
# prediction: 175.01, target value: 178

# %%
# plot cost versus iteration  
fig, (ax1, ax2) = plt.subplots(1, 2, constrained_layout=True, figsize=(12, 4))
ax1.plot(J_hist)
ax2.plot(100 + np.arange(len(J_hist[100:])), J_hist[100:])
ax1.set_title("Cost vs. iteration");  ax2.set_title("Cost vs. iteration (tail)")
ax1.set_ylabel('Cost')             ;  ax2.set_ylabel('Cost') 
ax1.set_xlabel('iteration step')   ;  ax2.set_xlabel('iteration step') 
plt.show()
